# %%
import numpy

from xmlschema import XMLSchema
from qe_tools import CONSTANTS

from ase import Atoms

# %%
def parse_pw(xml_file):
    """Parse a Quantum Espresso XML output file."""

    xml_dict = XMLSchema('qes_230310.xsd').to_dict('relax.xml')

    cell = numpy.array(
        [ v for v in xml_dict['output']['atomic_structure']['cell'].values()]
    ) * CONSTANTS.bohr_to_ang
    symbols = [el['@name'] for el in xml_dict['output']['atomic_structure']['atomic_positions']['atom']]
    positions = numpy.array(
        [el['$'] for el in xml_dict['output']['atomic_structure']['atomic_positions']['atom']]
    ) * CONSTANTS.bohr_to_ang

    atoms = Atoms(
        cell=cell,
        positions=positions,
        symbols=symbols,
        pbc=True,
    )
    return {
        'ase': atoms,
        'energy': xml_dict['output']['total_energy']['etot'] * 2 * CONSTANTS.ry_to_ev,
        'forces': (
            numpy.array(xml_dict['output']['forces']['$']).reshape(xml_dict['output']['forces']['@dims'])
            * 2 * CONSTANTS.ry_to_ev / CONSTANTS.bohr_to_ang
        )
    }

# %%
parse_pw('relax.xml')
# Out:
# {'ase': Atoms(symbols='Si2', pbc=True, cell=[[3.348898268062178, 0.0, 1.9334873165488495], [1.1162994227207257, 3.1573715664993287, 1.9334873165488495], [0.0, 0.0, 3.866974633097699]]),
#  'energy': -308.54069951701086,
#  'forces': array([[ 6.04935743e-06, -6.61138551e-06],
#         [ 0.00000000e+00, -6.04935743e-06],
#         [ 6.61138551e-06,  0.00000000e+00]])}

# %%
positions = numpy.array([v['$'] for v in xml_dict['output']['atomic_structure']['atomic_positions']['atom']]) * CONSTANTS.bohr_to_ang
# Out:
# array([[3.34889827, 0.        , 1.93348732],
#        [1.11629942, 3.15737157, 1.93348732],
#        [0.        , 0.        , 3.86697463]])

# %%
xml_dict['output']['forces']
# Out:
# {'@rank': 2,
#  '@dims': [3, 2],
#  '$': [1.176412837056589e-07,
#   -1.285709907533565e-07,
#   0.0,
#   -1.176412837056589e-07,
#   1.285709907533565e-07,
#   0.0]}

# %%
# Out:
# array([[ 6.04935743e-06, -6.61138551e-06],
#        [ 0.00000000e+00, -6.04935743e-06],
#        [ 6.61138551e-06,  0.00000000e+00]])

# %%
# Out:
# 40.888292209588194
